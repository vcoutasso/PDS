# %%
import matplotlib.pyplot as plt
import numpy as np
import pds

w = np.linspace(-np.pi, np.pi, 1024)

L = 11

A = np.sin(w*L/2)/np.sin(w/2)

psi = -w*(L-1)/2

X = A*np.exp(1j*psi)

# %%
plt.plot(w, np.abs(X));

# %%
plt.plot(w, np.angle(X));

# %%
plt.plot(w, A);

# %%
plt.plot(w, psi);

# %%
wc = np.pi/4
n = np.arange(-20, 21)
x = pds.sinc(n, wc)

plt.stem(n, x);

# %% [markdown]
# ## DTFT

# %%
L = 11
n = np.arange(-10, 21)
# Retangulo usando funcao degrau
x = pds.u(n) - pds.u(n-L)

X, w = pds.dtft(x, n)

plt.plot(w, X);
# Out:
# /home/vcouto/Documents/Facul/PDS/.venv/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
Xa = np.exp(-1j*w*(L-1)/2) * np.sin(w*L/2)/(w/2)

pds.mse(X, Xa)
# Out:
# 0.017229104613083534

# %%
x = pds.u(n)

X, w = pds.dtft(x, n)

plt.plot(w, X);
# Out:
# /home/vcouto/Documents/Facul/PDS/.venv/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
n0 = 10
x = pds.u(n - n0)

X, w = pds.dtft(x, n)

plt.plot(w, X);
# Out:
# /home/vcouto/Documents/Facul/PDS/.venv/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
